# %% [markdown]
# # 🐍 جلسه آموزشی پایتون: شرط‌ها، حلقه‌ها و سیستم ارزیابی نمره و معدل
#
# ---
#
# در این جلسه یاد می‌گیریم چگونه با استفاده از **دستورات شرطی** (`if`, `elif`, `else`) و **حلقه‌ها** (`for`, `while`) تصمیم‌گیری منطقی در برنامه‌نویسی انجام دهیم و سپس از این مفاهیم در مثال‌های واقعی مانند سیستم ارزیابی نمره و محاسبه معدل استفاده کنیم.

# %% [markdown]
# ## مرور مباحث پایه
# پیش از شروع، یک مرور کوتاه بر دستورات پایه‌ای پایتون داریم:
#
# - `print()` برای نمایش خروجی
# - `input()` برای گرفتن ورودی از کاربر
# - `int()`, `float()`, `str()` برای تبدیل نوع داده (casting)
# - قالب‌بندی متن با `f-string`
# - قوانین نام‌گذاری متغیرها (`snake_case`, `camelCase`, `PascalCase`)

# %%
# Basic review of input, print, casting, and f-string
name = input("Enter your name: ")
age = int(input("Enter your age: "))
print(f"Hello {name}, you are {age} years old.")

# Casting examples
x = "12.7"
num = float(x)
print("Converted value:", num, "| Type:", type(num))

# %% [markdown]
# ---
# ## دستورات شرطی (`if`, `elif`, `else`)
# برای تصمیم‌گیری در برنامه از ساختار شرطی استفاده می‌کنیم.
#
# ساختار کلی:
# ```python
# if condition:
#     # اجرا اگر شرط درست باشد
# elif another_condition:
#     # اجرا اگر شرط دوم درست باشد
# else:
#     # اگر هیچ‌کدام درست نبود
# ```

# %%
# Basic if/elif/else example
number = int(input("Enter an integer: "))

if number > 0:
    print("Positive number")
elif number == 0:
    print("Zero")
else:+
    print("Negative number")
# Out:
# Enter an integer:  26
# Positive number

# %% [markdown]
# ### عملگرهای منطقی
# می‌توان چند شرط را با هم ترکیب کرد:
#
# - `and` (و) → هر دو شرط باید درست باشند
# - `or` (یا) → یکی از شرط‌ها کافیست
# - `not` (نفی) → درست را نادرست و برعکس می‌کند

# %%
# Logical operator examples
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

if a > 0 and b > 0:
    print("Both numbers are positive")

if a > 10 or b > 10:
    print("At least one number is greater than 10")

flag = True
if flag:
    print("Flag is true")
# Out:
# Enter first number:  267
# Enter second number:  8569
# Both numbers are positive
# At least one number is greater than 10
# Flag is true

# %% [markdown]
# ---
# ## 🎯 مثال واقعی ۱: سیستم ارزیابی نمره (Grade System)
#
# در این مثال، کاربر نمره‌ی خود را وارد می‌کند و برنامه بر اساس بازه نمره، سطح عملکرد را مشخص می‌کند:
#
# | نمره | سطح | توضیح |
# |------|------|--------|
# | ۱۸ تا ۲۰ | A | عالی |
# | ۱۴ تا ۱۷.۹ | B | خوب |
# | ۱۰ تا ۱۳.۹ | C | قابل قبول |
# | کمتر از ۱۰ | F | مردود |

# %%
# Grade evaluation system (0–20 scale)
score = float(input("Enter your score (0–20): "))

if score > 20:
    print("Your input is not valid.")
elif score < 0:
    print("Your input is not valid.")
else:
    if score >= 18:
        grade = "A"
        remark = "Excellent"
    elif score >= 14:
        grade = "B"
        remark = "Good"
    elif score >= 10:
        grade = "C"
        remark = "Pass"
    else:
        grade = "F"
        remark = "Fail"

    print(f"Score: {score} | Grade: {grade} | Remark: {remark}")
# Out:
# Enter your score (0–20):  20.1
# Your input is not valid.
